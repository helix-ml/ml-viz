# %%
import icicle_plot
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('openml_sklearn_workflows.csv')
# df.groupby(['user_id', 'task_id']).size().sort_values(ascending=False)

# %%
# uid = 2489
# tid = 167132

# small dataset
# uid = 4916
# tid = 167132

uid = 8323
tid = 146825

ut_pair = df[(df['user_id'] == uid) & (df['task_id'] == tid) ]

def clean_model_names(row):
    model_comps = row.split(",")
    for j in range(len(model_comps)):
        model_comps[j] = model_comps[j].split(".")[len(model_comps[j].split(".")) - 1]
    row = ", ".join(model_comps)
    return row.replace("\'", "").replace("}", "").replace("{", "")

def clean_model_params(row):
    comps = row.split("(")
    filtered = {}
    for i in comps:
        if "null" not in i and len(i) > 4 and "random_state" not in i:
            clean = i.replace("\'", "").replace(")", "").replace("}", "")
            comps_clean = clean.split(",")
            comps_clean_filtered = []
            for j in comps_clean:
                if not (len(j) == 0 or j == " "):
                    comps_clean_filtered.append(j)
            filtered[comps_clean_filtered[0]] = comps_clean_filtered[1].replace(" ", "").replace("\"", "")
    return filtered
#             if 'n_'
#     print(filtered)
    
def expand_change_types(row):
    diction = {'S': 'Starting iteration',
'M': 'Model operator change',
'P': 'Preprocessing operator change',
'H': 'Model Hyperparameter change',
'R': 'Preprocessing hyperparameter change',
'C': 'Combination of model and preprocessing changes',
'N': 'No change'}
    
    return diction[row]
    
ut_pair.model = ut_pair.model.apply(clean_model_names)
ut_pair.change_type = ut_pair.change_type.apply(expand_change_types)
ut_pair.model_params = ut_pair.model_params.apply(clean_model_params)
ut_pair
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              rid  user_id  task_id       auc  dist_from_mean_auc  \
# 303496  10228615     8323   146825  0.968236            0.047679
# 303711  10228912     8323   146825  0.499516           -0.421041
# 304529  10229745     8323   146825  0.931338            0.010781
# 304572  10229788     8323   146825  0.994321            0.073764
# 304574  10229790     8323   146825  0.994364            0.073807
# ...          ...      ...      ...       ...                 ...
# 413728  10339060     8323   146825  0.990309            0.069751
# 413742  10339074     8323   146825  0.985725            0.065168
# 414095  10339427     8323   146825  0.993887            0.073330
# 414315  10339647     8323   146825  0.976209            0.055651
# 414342  10339674     8323   146825  0.985725            0.065168
#
#                                  model  \
# 303496  HistGradientBoostingClassifier
# 303711                       LinearSVC
# 304529  HistGradientBoostingClassifier
# 304572  HistGradientBoostingClassifier
# 304574  HistGradientBoostingClassifier
# ...                                ...
# 413728  HistGradientBoostingClassifier
# 413742  HistGradientBoostingClassifier
# 414095  HistGradientBoostingClassifier
# 414315  HistGradientBoostingClassifier
# 414342  HistGradientBoostingClassifier
#
#                                              model_params  \
# 303496  {'l2_regularization': '0.0', 'learning_rate': ...
# 303711  {'C': '1.0', 'dual': 'true', 'fit_intercept': ...
# 304529  {'l2_regularization': '1e-10', 'learning_rate'...
# 304572  {'l2_regularization': '1e-08', 'learning_rate'...
# 304574  {'l2_regularization': '1e-10', 'learning_rate'...
# ...                                                   ...
# 413728  {'l2_regularization': '0.001', 'learning_rate'...
# 413742  {'l2_regularization': '1e-09', 'learning_rate'...
# 414095  {'l2_regularization': '0.1', 'learning_rate': ...
# 414315  {'l2_regularization': '0.001', 'learning_rate'...
# 414342  {'l2_regularization': '1e-06', 'learning_rate'...
#
#                                                       ppr  \
# 303496             {'sklearn.impute._base.SimpleImputer'}
# 303711  {'sklearn_extra.kernel_approximation._fastfood...
# 304529             {'sklearn.impute._base.SimpleImputer'}
# 304572             {'sklearn.impute._base.SimpleImputer'}
# 304574             {'sklearn.impute._base.SimpleImputer'}
# ...                                                   ...
# 413728             {'sklearn.impute._base.SimpleImputer'}
# 413742             {'sklearn.impute._base.SimpleImputer'}
# 414095             {'sklearn.impute._base.SimpleImputer'}
# 414315             {'sklearn.impute._base.SimpleImputer'}
# 414342             {'sklearn.impute._base.SimpleImputer'}
#
#                                                ppr_params  iter  \
# 303496  {(('add_indicator', 'false'), ('copy', 'true')...     1
# 303711  {(('n_components', '10'), ('random_state', '1'...     2
# 304529  {(('add_indicator', 'false'), ('copy', 'true')...     3
# 304572  {(('add_indicator', 'false'), ('copy', 'true')...     4
# 304574  {(('add_indicator', 'false'), ('copy', 'true')...     5
# ...                                                   ...   ...
# 413728  {(('add_indicator', 'false'), ('copy', 'true')...   299
# 413742  {(('add_indicator', 'false'), ('copy', 'true')...   300
# 414095  {(('add_indicator', 'false'), ('copy', 'true')...   301
# 414315  {(('add_indicator', 'false'), ('copy', 'true')...   302
# 414342  {(('add_indicator', 'false'), ('copy', 'true')...   303
#
#                                            change_type  delta_auc  \
# 303496                              Starting iteration        NaN
# 303711  Combination of model and preprocessing changes  -0.468720
# 304529  Combination of model and preprocessing changes   0.431823
# 304572                     Model Hyperparameter change   0.062983
# 304574                     Model Hyperparameter change   0.000043
# ...                                                ...        ...
# 413728                     Model Hyperparameter change  -0.002685
# 413742                     Model Hyperparameter change  -0.004584
# 414095                     Model Hyperparameter change   0.008162
# 414315                     Model Hyperparameter change  -0.017678
# 414342                     Model Hyperparameter change   0.009516
#
#                  start_time  time_delta_in_mins
# 303496  2019-06-16 05:59:23                 NaN
# 303711  2019-06-26 08:47:16        14567.883333
# 304529  2019-07-15 06:03:59        27196.716667
# 304572  2019-07-15 08:32:44          148.750000
# 304574  2019-07-15 08:45:03           12.316667
# ...                     ...                 ...
# 413728  2019-08-20 21:53:04            1.816667
# 413742  2019-08-20 21:58:48            5.733333
# 414095  2019-08-20 22:54:40           55.866667
# 414315  2019-08-20 23:33:42           39.033333
# 414342  2019-08-20 23:39:48            6.100000
#
# [303 rows x 14 columns]

# %%
hyperparams_df = 0

def sorting_criteria(s):
    return len(hyperparams_df[s].unique())

hp_key = {}
max_len_candidates = 0
for model_iter in ut_pair.model.unique():
    hyperparams_df = pd.DataFrame(ut_pair[ut_pair.model == model_iter].model_params.to_list())
    hp_candidates = sorted(list(ut_pair[ut_pair.model == model_iter].model_params.to_list()[0].keys()), key=sorting_criteria)
    hp_candidates = [i for i in hp_candidates if len(hyperparams_df[i].unique()) > 1]
    hp_key[model_iter] = hp_candidates
    if len(hp_candidates) > max_len_candidates:
        max_len_candidates = len(hp_candidates)
        
hyperparams_df = pd.DataFrame(ut_pair.model_params.to_list())
hyperparams_df['rid'] = ut_pair.rid.values

# print(hyperparams_df.rid)

current_index = 0
def hp_viz_creator(row):
#     print(row)
    if current_index < len(hp_key[row.model]):
        hp_value = str(hyperparams_df[hyperparams_df.rid == row.rid][hp_key[row.model][current_index]].tolist()[0])
        return hp_key[row.model][current_index] + "=" + hp_value
    return None


for i in range(max_len_candidates):
#     print(ut_pair)
    current_index = i
    ut_pair[str(i) + "_order_hyp"] = ut_pair[['model', 'rid']].apply(hp_viz_creator,axis=1)
    
ut_pair
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              rid  user_id  task_id       auc  dist_from_mean_auc  \
# 303496  10228615     8323   146825  0.968236            0.047679
# 303711  10228912     8323   146825  0.499516           -0.421041
# 304529  10229745     8323   146825  0.931338            0.010781
# 304572  10229788     8323   146825  0.994321            0.073764
# 304574  10229790     8323   146825  0.994364            0.073807
# ...          ...      ...      ...       ...                 ...
# 413728  10339060     8323   146825  0.990309            0.069751
# 413742  10339074     8323   146825  0.985725            0.065168
# 414095  10339427     8323   146825  0.993887            0.073330
# 414315  10339647     8323   146825  0.976209            0.055651
# 414342  10339674     8323   146825  0.985725            0.065168
#
#                                  model  \
# 303496  HistGradientBoostingClassifier
# 303711                       LinearSVC
# 304529  HistGradientBoostingClassifier
# 304572  HistGradientBoostingClassifier
# 304574  HistGradientBoostingClassifier
# ...                                ...
# 413728  HistGradientBoostingClassifier
# 413742  HistGradientBoostingClassifier
# 414095  HistGradientBoostingClassifier
# 414315  HistGradientBoostingClassifier
# 414342  HistGradientBoostingClassifier
#
#                                              model_params  \
# 303496  {'l2_regularization': '0.0', 'learning_rate': ...
# 303711  {'C': '1.0', 'dual': 'true', 'fit_intercept': ...
# 304529  {'l2_regularization': '1e-10', 'learning_rate'...
# 304572  {'l2_regularization': '1e-08', 'learning_rate'...
# 304574  {'l2_regularization': '1e-10', 'learning_rate'...
# ...                                                   ...
# 413728  {'l2_regularization': '0.001', 'learning_rate'...
# 413742  {'l2_regularization': '1e-09', 'learning_rate'...
# 414095  {'l2_regularization': '0.1', 'learning_rate': ...
# 414315  {'l2_regularization': '0.001', 'learning_rate'...
# 414342  {'l2_regularization': '1e-06', 'learning_rate'...
#
#                                                       ppr  \
# 303496             {'sklearn.impute._base.SimpleImputer'}
# 303711  {'sklearn_extra.kernel_approximation._fastfood...
# 304529             {'sklearn.impute._base.SimpleImputer'}
# 304572             {'sklearn.impute._base.SimpleImputer'}
# 304574             {'sklearn.impute._base.SimpleImputer'}
# ...                                                   ...
# 413728             {'sklearn.impute._base.SimpleImputer'}
# 413742             {'sklearn.impute._base.SimpleImputer'}
# 414095             {'sklearn.impute._base.SimpleImputer'}
# 414315             {'sklearn.impute._base.SimpleImputer'}
# 414342             {'sklearn.impute._base.SimpleImputer'}
#
#                                                ppr_params  iter  ...  \
# 303496  {(('add_indicator', 'false'), ('copy', 'true')...     1  ...
# 303711  {(('n_components', '10'), ('random_state', '1'...     2  ...
# 304529  {(('add_indicator', 'false'), ('copy', 'true')...     3  ...
# 304572  {(('add_indicator', 'false'), ('copy', 'true')...     4  ...
# 304574  {(('add_indicator', 'false'), ('copy', 'true')...     5  ...
# ...                                                   ...   ...  ...
# 413728  {(('add_indicator', 'false'), ('copy', 'true')...   299  ...
# 413742  {(('add_indicator', 'false'), ('copy', 'true')...   300  ...
# 414095  {(('add_indicator', 'false'), ('copy', 'true')...   301  ...
# 414315  {(('add_indicator', 'false'), ('copy', 'true')...   302  ...
# 414342  {(('add_indicator', 'false'), ('copy', 'true')...   303  ...
#
#        delta_auc           start_time time_delta_in_mins  \
# 303496       NaN  2019-06-16 05:59:23                NaN
# 303711 -0.468720  2019-06-26 08:47:16       14567.883333
# 304529  0.431823  2019-07-15 06:03:59       27196.716667
# 304572  0.062983  2019-07-15 08:32:44         148.750000
# 304574  0.000043  2019-07-15 08:45:03          12.316667
# ...          ...                  ...                ...
# 413728 -0.002685  2019-08-20 21:53:04           1.816667
# 413742 -0.004584  2019-08-20 21:58:48           5.733333
# 414095  0.008162  2019-08-20 22:54:40          55.866667
# 414315 -0.017678  2019-08-20 23:33:42          39.033333
# 414342  0.009516  2019-08-20 23:39:48           6.100000
#
#                     0_order_hyp         1_order_hyp         2_order_hyp  \
# 303496  validation_fraction=0.1   learning_rate=0.1   max_leaf_nodes=31
# 303711                     None                None                None
# 304529  validation_fraction=0.1   learning_rate=0.1   max_leaf_nodes=16
# 304572  validation_fraction=0.2   learning_rate=0.1   max_leaf_nodes=32
# 304574  validation_fraction=0.1   learning_rate=0.1  max_leaf_nodes=128
# ...                         ...                 ...                 ...
# 413728  validation_fraction=0.2   learning_rate=0.1    max_leaf_nodes=4
# 413742  validation_fraction=0.2  learning_rate=0.01    max_leaf_nodes=4
# 414095  validation_fraction=0.1   learning_rate=0.1  max_leaf_nodes=128
# 414315  validation_fraction=0.2   learning_rate=0.1   max_leaf_nodes=16
# 414342  validation_fraction=0.2  learning_rate=0.01    max_leaf_nodes=4
#
#          3_order_hyp   4_order_hyp              5_order_hyp  \
# 303496  max_bins=256  max_iter=100    l2_regularization=0.0
# 303711          None          None                     None
# 304529    max_bins=8  max_iter=300  l2_regularization=1e-10
# 304572   max_bins=16  max_iter=350  l2_regularization=1e-08
# 304574   max_bins=64  max_iter=200  l2_regularization=1e-10
# ...              ...           ...                      ...
# 413728    max_bins=2  max_iter=400  l2_regularization=0.001
# 413742   max_bins=64  max_iter=450  l2_regularization=1e-09
# 414095  max_bins=256  max_iter=350    l2_regularization=0.1
# 414315  max_bins=256  max_iter=350  l2_regularization=0.001
# 414342   max_bins=64  max_iter=450  l2_regularization=1e-06
#
#                 6_order_hyp
# 303496  min_samples_leaf=20
# 303711                 None
# 304529  min_samples_leaf=15
# 304572  min_samples_leaf=18
# 304574  min_samples_leaf=10
# ...                     ...
# 413728  min_samples_leaf=20
# 413742   min_samples_leaf=3
# 414095  min_samples_leaf=11
# 414315   min_samples_leaf=9
# 414342  min_samples_leaf=18
#
# [303 rows x 21 columns]

# %%
import numpy as np
hierarchy_path = ['model'] + [str(i) + '_order_hyp' for i in range(max_len_candidates)]
ut_p = ut_pair[hierarchy_path + ['dist_from_mean_auc']]
def recur_dictify(frame):
    if len(frame.columns) == 1:
        if frame.values.size == 1: return frame.values[0][0]
        return frame.values.squeeze()
    
    # for rows that contain None values (have fewer hyperparameters than others)
    if frame[frame.columns[0]].iloc[0] == None:
        return frame.values[0][len(frame.values[0])-1]
    grouped = frame.groupby(frame.columns[0])
    d = {k: recur_dictify(g.iloc[:,1:]) for k,g in grouped}
    return d
ut_p = recur_dictify(ut_p)
low_color = 2.0
high_color = -1.0
def recur_hierarch(frame):
    global low_color
    global high_color
    if isinstance(frame, np.float64) or isinstance(frame, float) or isinstance(frame, np.ndarray):
        if isinstance(frame, np.ndarray):
            return frame[0], frame[0]
        return frame, frame
    children = []
    colors = []
    for key in frame.keys():
        children_c, color = recur_hierarch(frame[key])
        colors.append(color)
        
        if children_c != [] and not isinstance(children_c, float) and not isinstance(children_c[0], np.float64):
            # node
            
            children.append({'name': key, 'color': color, 'children': children_c})
        else:
            # leaf
            if color < low_color:
                low_color = color
            if color > high_color:
                high_color = color
            children.append({'name': key, 'color': color, 'size': 1})
    return children, max(colors)

children_ut_p, color = recur_hierarch(ut_p)
ut_p = {'name': 'main', 'color': color, 'children': children_ut_p}
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:31: DeprecationWarning:
#
# The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.

# %%
import json

from jupyter_dash import JupyterDash
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

ut_pair = ut_pair.drop_duplicates(subset=hierarchy_path)

app = JupyterDash(__name__)
# app = dash.Dash()
app.css.config.serve_locally = True
app.scripts.config.serve_locally = True

def df_to_dict(ut):
    data = {}
    for col_name in hierarchy_path:
        for i, g in ut.groupby(col_name):
            data_key = g[col_name].iloc[0]
            data[data_key] = {}

data = ut_p

fig = icicle_plot.Icicle(
    id='icicle',
    value='my-value',
    label='my-label',
    low=low_color,
    high=high_color,
    data=data
)

def make_ints(row):
    for col in hierarchy_path:
        if row[col] != None:
            try:
                row[col] = float(row[col].split("=")[1])
            except:
                row[col]
    return row

ut_pair_numeric = ut_pair.apply(make_ints, axis=1)

pc = px.parallel_coordinates(ut_pair_numeric, color="dist_from_mean_auc", dimensions=hierarchy_path,
                             color_continuous_scale='RdBu')
pc_o = pc

app.layout = html.Div([
    fig,
    dcc.Graph(
        id='pc',
        figure=pc
    ),
    html.Div(id='output')
])

@app.callback(
    Output('pc', 'figure'),
    [Input('icicle', 'value')])
def display_click_data(clickData):
    global pc
    if clickData.split("/")[:-1] == []:
        return pc
    if clickData:
        click_path = clickData.split("/")[:-1][1:]
        subset_counter = len(click_path)
        if click_path == []:
            return pc_o
        
        selected_df = ut_pair
        j = -1
        for i in click_path:
            j+=1
            if "=" in i:
                comps_name = i.split("=")
                hyp_name = comps_name[0]
                hyp_val = comps_name[1]
                selected_df = selected_df[selected_df.apply(lambda x: x['model_params'][hyp_name] == hyp_val if hyp_name in x['model_params'] else False, axis=1)]
            else:
                selected_df = selected_df[selected_df['model'] == i]
        sample_vals = selected_df.iloc[0]
        labels_pc = {}
        for i in hierarchy_path[subset_counter:]:
            if sample_vals[i]:
                labels_pc[i] = sample_vals[i].split("=")[0]
        
        selected_df = selected_df.apply(make_ints, axis=1)
        
        pc = px.parallel_coordinates(selected_df, color="dist_from_mean_auc", dimensions=hierarchy_path[subset_counter:],
                                 labels=labels_pc, color_continuous_scale='RdBu')
        
        return pc
    pc = px.parallel_coordinates(ut_pair_numeric, color="dist_from_mean_auc", dimensions=hierarchy_path,
                             color_continuous_scale='RdBu')
    return pc

app.run_server(mode='inline', port=8200)
# app.run_server(port=8090)
# Out:
#         <iframe
#             width="800"
#             height="650"
#             src="http://127.0.0.1:8200/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
